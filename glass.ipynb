# %%
import pandas as pd 
a=pd.read_excel('glass-door.xlsx',sheet_name='copy')
print(a.info())
print(a.describe())
print(a.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      899 non-null    object
#  1   job_title                    900 non-null    object
#  2   company_rating               656 non-null    float64
#  3   location                     900 non-null    object
#  4   salary_avg_estimate          636 non-null    float64
#  5   salary_estimate_payperiod    636 non-null    object
#  6   company_size                 774 non-null    object
#  7   company_founded              774 non-null    object
#  8   employment_type              774 non-null    object
#  9   industry                     774 non-null    object
#  10  sector                       774 non-null    object
#  11  revenue                      774 non-null    object
#  12  career_opportunities_rating  731 non-null    float64
# ...

# %%
b=a.dropna()
print(b.info())
#print(a.describe())
print(b.to_string())
b.to_excel('removed empty.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 467 entries, 0 to 898
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      467 non-null    object
#  1   job_title                    467 non-null    object
#  2   company_rating               467 non-null    float64
#  3   location                     467 non-null    object
#  4   salary_avg_estimate          467 non-null    float64
#  5   salary_estimate_payperiod    467 non-null    object
#  6   company_size                 467 non-null    object
#  7   company_founded              467 non-null    object
#  8   employment_type              467 non-null    object
#  9   industry                     467 non-null    object
#  10  sector                       467 non-null    object
#  11  revenue                      467 non-null    object
#  12  career_opportunities_rating  467 non-null    float64
# ...
